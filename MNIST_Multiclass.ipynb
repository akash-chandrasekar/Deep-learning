# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator

# %%
train_data=ImageDataGenerator(rescale=1/225,shear_range=0.2,zoom_range=0.2,horizontal_flip=True,vertical_flip=True)

# %%
test_data=ImageDataGenerator(rescale=1/225)

# %%
train_data_generator=train_data.flow_from_directory(directory="/content/drive/MyDrive/Colab Notebooks/DL/Day07/Train_Data",target_size=(256,256))
# Out:
# Found 14 images belonging to 3 classes.

# %%
test_data_generator=train_data.flow_from_directory(directory="/content/drive/MyDrive/Colab Notebooks/DL/Day07/Test_Data",target_size=(256,256))
# Out:
# Found 8 images belonging to 3 classes.

# %%
train_data_generator.class_indices
# Out:
# {'Rock': 0, 'Shahrukh': 1, 'Tom': 2}

# %%
test_data_generator.class_indices
# Out:
# {'Rock': 0, 'Shah': 1, 'tom': 2}

# %%
train_data_generator.image_shape
# Out:
# (256, 256, 3)

# %%
from keras import Sequential
from keras.layers import Conv2D,MaxPool2D,Flatten,Dense

# %%
model=Sequential()

model.add(Conv2D(input_shape=(256,256,3),filters=8,kernel_size=(3,3),strides=(1, 1), padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2), strides=2))

model.add(Conv2D(filters=8,kernel_size=(3,3),strides=(1, 1), padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2), strides=2))

model.add(Conv2D(filters=16,kernel_size=(3,3),strides=(1, 1), padding='same',activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2), strides=2))

model.add(Flatten())
model.add(Dense(units=30, activation="relu"))
model.add(Dense(units=3 ,activation='softmax'))

model.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_22 (Conv2D)          (None, 256, 256, 8)       224
#
#  max_pooling2d_19 (MaxPoolin  (None, 128, 128, 8)      0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 128, 128, 8)       584
#
#  max_pooling2d_20 (MaxPoolin  (None, 64, 64, 8)        0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 64, 64, 16)        1168
#
#  max_pooling2d_21 (MaxPoolin  (None, 32, 32, 16)       0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 16384)             0
#
#  dense_1 (Dense)             (None, 30)                491550
#
#  dense_2 (Dense)             (None, 3)                 93
#
# ...
# Total params: 493,619
# Trainable params: 493,619
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='rmsprop', loss="categorical_crossentropy", metrics="accuracy")

# %%
model=model.fit(x=train_data_generator, epochs=10,validation_data=(test_data_generator))
# Out:
# Epoch 1/10
# 1/1 [==============================] - 6s 6s/step - loss: 1.0818 - accuracy: 0.4286 - val_loss: 2.2103 - val_accuracy: 0.3750
# Epoch 2/10
# 1/1 [==============================] - 2s 2s/step - loss: 3.1362 - accuracy: 0.2857 - val_loss: 2.3327 - val_accuracy: 0.2500
# Epoch 3/10
# 1/1 [==============================] - 2s 2s/step - loss: 2.1827 - accuracy: 0.4286 - val_loss: 1.2526 - val_accuracy: 0.3750
# Epoch 4/10
# 1/1 [==============================] - 2s 2s/step - loss: 1.2054 - accuracy: 0.3571 - val_loss: 1.1870 - val_accuracy: 0.2500
# Epoch 5/10
# 1/1 [==============================] - 1s 1s/step - loss: 1.1221 - accuracy: 0.4286 - val_loss: 1.1369 - val_accuracy: 0.3750
# Epoch 6/10
# 1/1 [==============================] - 2s 2s/step - loss: 1.0559 - accuracy: 0.6429 - val_loss: 1.0703 - val_accuracy: 0.3750
# Epoch 7/10
# 1/1 [==============================] - 1s 1s/step - loss: 0.9980 - accuracy: 0.6429 - val_loss: 1.0686 - val_accuracy: 0.5000
# Epoch 8/10
# ...
